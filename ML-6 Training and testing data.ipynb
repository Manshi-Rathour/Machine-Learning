# %%
import pandas as pd
df = pd.read_csv('carprice.csv')
df.head()
# Out:
#    Mileage  Age  Sell Price
# 0    69000    6       18000
# 1    35000    3       34000
# 2    57000    5       26100
# 3    22500    2       40000
# 4    46000    4       31500

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['Mileage'], df['Sell Price'])

# %%
plt.scatter(df['Age'], df['Sell Price'])

# %%
x = df[['Mileage', 'Age']]
y = df['Sell Price']

# %%
x
# Out:
#     Mileage  Age
# 0     69000    6
# 1     35000    3
# 2     57000    5
# 3     22500    2
# 4     46000    4
# 5     59000    5
# 6     52000    5
# 7     72000    6
# 8     91000    8
# 9     67000    7
# 10    83000    7
# 11    79000    5
# 12    59000    4
# 13    58780    7
# 14    82450    3
# 15    25400    2
# 16    28000    5
# 17    69000    8
# 18    87600    5
# 19    52000    6

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
len(x_train)
# Out:
# 16

# %%
x_train
# Out:
#     Mileage  Age
# 9     67000    7
# 3     22500    2
# 17    69000    8
# 13    58780    7
# 2     57000    5
# 10    83000    7
# 14    82450    3
# 4     46000    4
# 7     72000    6
# 1     35000    3
# 18    87600    5
# 15    25400    2
# 8     91000    8
# 5     59000    5
# 6     52000    5
# 11    79000    5

# %%
len(x_test)
# Out:
# 4

# %%
x_test
# Out:
#     Mileage  Age
# 12    59000    4
# 16    28000    5
# 0     69000    6
# 19    52000    6

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
clf.predict(x_test)
# Out:
# array([25934.21095557, 36864.8194327 , 21973.04579611, 28069.99712851])

# %%
y_test
# Out:
# 12    26000
# 16    35500
# 0     18000
# 19    28200
# Name: Sell Price, dtype: int64

# %%
clf.score(x_test, y_test)
# Out:
# 0.8864949078851823
